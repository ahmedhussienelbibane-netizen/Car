# %% [markdown]
# Model was trained on kaggle and best results were downloaded to test on local env
#
# below is kaggle code

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="my kaggle api key ")
project = rf.workspace("aa-x3mix").project("parking-b8jq9")
version = project.version(1)
dataset = version.download("yolov8-obb")

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')

# %%
model.train(
    data='/kaggle/working/parking-1/data.yaml',
    epochs=100,
    imgsz=640,
    batch=8,
)

# %% [markdown]
# Best.pt was downloaded from kaggle, and here is the test code on local enviroment

# %%
from ultralytics import YOLO

model = YOLO("best.pt")

results = model.predict(
    source="/mnt/d/Car/29_05_20201.mp4",
    save=True,
    line_thickness=2,
    project="/mnt/d/Car/results"
)
# Out:
# WARNING ⚠️ 'line_thickness' is deprecated and will be removed in the future. Use 'line_width' instead.
#
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/357) /mnt/d/Car/29_05_20201.mp4: 384x640 1 empty, 66 occupieds, 48.6ms
# video 1/1 (frame 2/357) /mnt/d/Car/29_05_20201.mp4: 384x640 1 empty, 63 occupieds, 7.7ms
# video 1/1 (frame 3/357) /mnt/d/Car/29_05_20201.mp4: 384x640 1 empty, 68 occupieds, 8.3ms
# ...

# %%
model.save("Parking_spots_detector")
